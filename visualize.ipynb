# %% [markdown]
# # Cluster Visualization

# %%
# load in the file
import pandas as pd
import numpy

df = pd.read_pickle('2.pkl')

# %%
import torch

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.636021 -1.722632 -1.330498 -0.130354 -1.163336 -1.713651 -1.230310
# 1  0.863301 -2.285797 -1.890812  0.992313 -2.076022 -0.530970  0.274220
# 2 -0.514528 -0.040220 -1.446526  1.718915 -1.844131 -2.073348  0.138912
# 3 -0.641315  0.660790 -0.652155  1.937758  0.002327 -0.474403 -1.708515
# 4 -0.851546 -0.810696  0.471626  2.522490 -0.741130  1.256366 -1.192604
#
#           7         8         9  ...       376       377       378       379  \
# 0  0.811860  0.079177 -1.785028  ... -0.362672 -0.084192  0.666860 -2.085680
# 1  1.102819  0.443971 -2.013194  ... -0.352910  0.284432 -0.176623 -1.409961
# 2  2.506224  0.252722 -2.065618  ... -1.106079 -0.995504 -0.913891 -0.960365
# 3  0.774177 -0.322695  0.571385  ... -0.684443 -0.280992 -1.347694 -3.228458
# 4  0.250783  0.668604 -2.305680  ...  0.304804 -1.397990 -0.581071 -1.741081
#
#         380       381       382       383    token  label
# 0  1.181556  0.451658 -2.633628  1.305333      One      6
# 1  2.622753 -0.533689 -1.251574  0.677157      day      6
# 2  0.978620 -0.776910 -1.148486  2.081278        ,      6
# 3  0.968970  1.290327 -0.637321  0.134732        a      6
# 4  0.452723 -0.989166 -1.525525  0.798011   little      6
#
# [5 rows x 386 columns]

# %%
# Extract the numeric values (the outbedding columns)
outbeddings_array = df.iloc[:, :-2].values  # Exclude the 'token' and 'label' columns

# %%
tokens = df['token']
outbeddings = outbeddings_array
best_labels = df['label']

# %%
import umap.umap_ as umap
import plotly.express as px
import numpy as np

# Reduce to 2D using UMAP
umap_reducer = umap.UMAP(n_components=2, random_state=42)
reduced_data = umap_reducer.fit_transform(outbeddings)

# Create a DataFrame for visualization
import pandas as pd
data = pd.DataFrame(reduced_data, columns=["UMAP Dimension 1", "UMAP Dimension 2"])
data["Token"] = tokens  # Add tokens
data["Cluster"] = best_labels  # Add cluster labels
data["Index"] = [i for i in range(len(data))]

# Plot with Plotly
fig = px.scatter(
    data,
    x="UMAP Dimension 1",
    y="UMAP Dimension 2",
    color="Cluster",
    text="Token",  # This will show the token on hover
    title="Token Cluster Visualization",
)

# Update traces to show token and index only on hover
fig.update_traces(
    marker=dict(size=8),
    customdata=data[["Token", "Index"]].values,  # Attach tokens and index to customdata
    hovertemplate="<b>Token:</b> %{customdata[0]}<br>"
                  "<b>Index:</b> %{customdata[1]}<br>"
                  "<b>Cluster:</b> %{marker.color}<extra></extra>",  # Custom hover format
    text=None,  # Disable text labels
    hoverinfo="skip",  # Suppress default hover info
)

# Show the interactive plot
fig.show()
# Out:
# /Users/isabella_zhu/nanoGPT/env/lib/python3.12/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/isabella_zhu/nanoGPT/env/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %%
import plotly.io as pio
pio.write_html(fig, file="cluster_visual.html", auto_open=False)
